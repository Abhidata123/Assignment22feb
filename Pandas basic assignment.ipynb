# %% [markdown]
# Q1. Create a Pandas Series that contains the following data: 4, 8, 15, 16, 23, and 42. Then, print the series.

# %%
import pandas as pd

# %%
s = [4,8,15,16,23,42]

# %%
df= pd.Series(s)

# %%
df
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %%
type(df)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Q2. Create a variable of list type containing 10 elements in it, and apply pandas.Series function on the
# variable print it.

# %%
d = ['Abhi', 'Krish', 'Pandas','Numpy','Python','Data Science', 'Visualization', 'Regression Engineering', 'Image Scraping','Youtube scrapping']

# %%
df2 = pd.Series(d)

# %%
type(df2)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Q3. Create a Pandas DataFrame that contains the following data:

# %%
k = {'Name': ['Alice','Bob','Claire'], 'Age': [25,30,27], 'Gender':['Female','Male','Female']}

# %%
df3 = pd.DataFrame(k)

# %%
df3
# Out:
#      Name  Age  Gender
# 0   Alice   25  Female
# 1     Bob   30    Male
# 2  Claire   27  Female

# %% [markdown]
# Q4. What is ‘DataFrame’ in pandas and how is it different from pandas.series? Explain with an example.

# %% [markdown]
# Ans4: A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns. Pandas DataFrame consists of three principal components, the data, rows, and columns.

# %%
lst = ['Geeks', 'For', 'Geeks', 'is', 
            'portal', 'for', 'Geeks']
df4 = pd.DataFrame(lst)

df4
# Out:
#         0
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %% [markdown]
# Ans4: Pandas Series : The Pandas Series data structure is a one-dimensional labelled array. It is the primary building block for a DataFrame, making up its rows and columns. You can view the constructor for the Series below.

# %%
data = {'a': 1.0, 'b': 2.0, 'c': 3.0, 'd': 4.0}
series = pd.Series(data)
series
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# dtype: float64

# %% [markdown]
# Q.5: What are some common functions you can use to manipulate data in a Pandas DataFrame? Can
# you give an example of when you might use one of these functions?

# %% [markdown]
# 1. We can read the dataframe by using head() function also which is having an argument (n) i.e. number of rows to be displayed.
# 2. Counting the rows and columns in DataFrame using shape(). It returns the no. of rows and columns enclosed in a tuple.
# 3. Summary of Statistics of DataFrame using describe() method.
# 4. Dropping the missing values in DataFrame, it can be done using the dropna() method, it removes all the NaN values in the dataframe.
# 5. Merging DataFrames using merge(), arguments passed are the dataframes to be merged along with the column name.
# 6. Renaming the columns of dataframe using rename(), arguments passed are the columns to be renamed & inplace.

# %%
df7 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df7.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df7.shape
# Out:
# (891, 12)

# %%
df7['Name'].describe()
# Out:
# count                         891
# unique                        891
# top       Braund, Mr. Owen Harris
# freq                            1
# Name: Name, dtype: object

# %%
df7.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
kd = df7.rename(columns = {'Name': 'Passangers Name'})

# %%
kd
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                        Passangers Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Q6. Which of the following is mutable in nature Series, DataFrame, Panel?

# %% [markdown]
# Ans:
# Series – 1D labeled homogeneous array, sizeimmutable
# Data Frames – 2D labeled, size-mutable tabular structure with heterogenic columns
# Panel – 3D labeled size mutable array.
#
# 1. Series in Pandas:
# Series is a one-dimensional array with homogeneous data.  All the elements of series should be of same data type.
# Key Features of a Series:
# Homogeneous data
# Size Immutable –size cannot be changed
# Values of Data Mutable
#
# 2. DataFrame in pandas:
# DataFrame is a two-dimensional array with heterogeneous data, usually represented in the tabular format. The data is represented in rows and columns. Each column represents an attribute and each row represents a person.
# Key Features of a DataFrame:
# Heterogeneous data
# Size Mutable
# Data Mutable
#
# 3. Panel in pandas:
# Panel is a three-dimensional data structure with heterogeneous data.
#
# Key Features of a Panel:
# Heterogeneous data
# Size Mutable
# Data Mutable

# %% [markdown]
# Q7. Create a DataFrame using multiple Series. Explain with an example.

# %%
courses = pd.Series(["Spark","PySpark","Hadoop"], name='courses')
fees = pd.Series([22000,25000,23000], name='fees')
discount  = pd.Series([1000,2300,1000],name='discount')
df9=pd.concat([courses,fees,discount],axis=1)

# %%
df9
# Out:
#    courses   fees  discount
# 0    Spark  22000      1000
# 1  PySpark  25000      2300
# 2   Hadoop  23000      1000
